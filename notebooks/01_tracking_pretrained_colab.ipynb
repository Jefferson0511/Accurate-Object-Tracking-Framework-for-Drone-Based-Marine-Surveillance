# %% [markdown]
# # Before Running the Script Please Make Sure you Select the Run Time as GPU

# %% [markdown]
# #**Clone the Github Repo**

# %%
# !git clone https://github.com/Jefferson0511/Accurate-Object-Tracking-Framework-for-Drone-Based-Marine-Surveillance.git

# %% [markdown]
# ##Setting the Current Directory

# %%
cd Accurate-Object-Tracking-Framework-for-Drone-Based-Marine-Surveillance

# %% [markdown]
# ##Install all the Dependencies

# %%
# !pip install -e '.[dev]'

# %% [markdown]
# ##Moving to the Required Directory

# %%
# %cd ultralytics/yolo/v8/detect

# %% [markdown]
# ##To implement the DeepSORT tracking, downloading the required files

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"

# %% [markdown]
# ##Unzipping the DeepSORT Files

# %%
# !unzip 'deep_sort_pytorch.zip'

# %% [markdown]
# ##Download a Sample Video for Testing from Google Drive

# %%
# !gdown https://drive.google.com/uc?id=1_kt1alzcLRVxet-Drx0mt_KFSd3vrtHU

# %% [markdown]
# ##Lets Run the Script

# %%
# !python predict.py source="test1.mp4"

# %% [markdown]
# ##Display the Demo Video

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/Accurate-Object-Tracking-Framework-for-Drone-Based-Marine-Surveillance/runs/detect/train/test1.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# ##Downloading the Script Files for Tracking and Vehicle Counting from Google Drive

# %%
# !gdown "https://drive.google.com/uc?id=1mV3xyYxz8fo8OZyMC_p1Jtv7jC458aSv&confirm=t"

# %% [markdown]
# ##Download the Demo Video

# %%
# !gdown "https://drive.google.com/uc?id=1rjBn8Fl1E_9d0EMVtL24S9aNQOJAveR5&confirm=t"

# %%
# !python predict.py source="test3.mp4"

# %% [markdown]
# ##Display the Demo Video

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/Accurate-Object-Tracking-Framework-for-Drone-Based-Marine-Surveillance/runs/detect/train2/test3.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
